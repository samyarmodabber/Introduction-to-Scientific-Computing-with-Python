# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mg
plt.axis("off")


path='Deutch.jpg'
img = mg.imread(path)

plt.imshow(img)
plt.show()


height, width = img.shape[0:2]
print(img.shape,height,width)
# Out:
# (477, 379, 3) 477 379

# %%
#getRotationMatrix2D(center, angle, scale)
rotationMatrix = cv2.getRotationMatrix2D((width/2, height/2), 45, 1.6)
print(rotationMatrix)
rotatedImage = cv2.warpAffine(img, rotationMatrix, (width, height))
plt.imshow(rotatedImage)
plt.show()
# Out:
# [[   1.13137085    1.13137085 -294.72672376]
#  [  -1.13137085    1.13137085  183.06282835]]

# %%
croppedImage = img[0:400, 100:200]
plt.imshow(croppedImage)
plt.show()

# %%
resizeImg = cv2.resize(img, (0,0), fx=0.8, fy=0.8)
plt.imshow(resizeImg)
plt.show()
print(resizeImg.shape)
# Out:
# (382, 303, 3)

# %%
contrast_img = cv2.addWeighted(img, 2.0, np.zeros(img.shape, img.dtype), 0, 0)
plt.imshow(contrast_img)
plt.show()

# %%
blur_image = cv2.GaussianBlur(img,(25,25),0)
plt.imshow(blur_image)
plt.show()

# %%
blur_image_med = cv2.medianBlur(img,25)
plt.imshow(blur_image_med)
plt.show()

# %%
edge_img = cv2.Canny(img,100,200)
plt.imshow(edge_img)

# %%
den_img = cv2.fastNlMeansDenoisingColored(img,None,20,10,7,21)
plt.imshow(den_img)
